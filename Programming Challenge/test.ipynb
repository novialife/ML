# %%
import pandas as pd
mervans = open("predictions.txt", "r")
daniels = open("Classes.txt", "r")

df_merv = pd.Series(mervans.read().splitlines())
df_dan = pd.Series(daniels.read().splitlines())

# %%
df_dan.value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='None'>

# %%
df_merv.value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='None'>

# %%
pd.read_csv("TrainOnMe-4.csv", index_col=0).y.value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='y'>
